# %%
# %matplotlib inline
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import matplotlib.pyplot as plt
from scipy.interpolate import InterpolatedUnivariateSpline, interp1d
from scipy.special import erfc
from astropy.io import fits
import pandas as pd
import seaborn as sns 
import itertools

# %%
zmin = 0.0
zmax = 1.5

mmin = 15.0
mmax = 26.0
nm = 11

fac = 100
nz_coarse = 30
nz_fine = nz_coarse*fac

z_grid_coarse = np.linspace(zmin, zmax, nz_coarse)
z_grid_fine = np.linspace(zmin, zmax, nz_fine)
ref_mag_grid = np.linspace(mmin, mmax, nm)

filters = ['g', 'r', 'i', 'z']
reffilter = 2

# ellipticals = ['El_B2004a.sed']
# spirals = ['Sbc_B2004a.sed','Scd_B2004a.sed']
# irregulars = ['Im_B2004a.sed','SB3_B2004a.sed','SB2_B2004a.sed','ssp_25Myr_z008.sed','ssp_5Myr_z008.sed']

ellipticals = ['El_cww_capak.sed']
spirals = ['Sbc_cww_capak.sed','Scd_cww_capak.sed']
irregulars = ['Im_cww_capak.sed','SB3_kin_capak.sed','SB2_kin_capak.sed']

template_names = [nm.replace('.sed','') for nm in ellipticals+spirals+irregulars]

nt = len(template_names)

# %% [markdown]
# # Read and clean catalogs

# %%
catalog = fits.open('DES_Y1_GOLD/Y1_GOLD_BPZ_100000.fits')[1]
data = catalog.data

# We only use objects which are not flagged to be excluded from analysis in GOLD
data = data[data['FLAGS_GOLD'] == 0]

# We apply a few arbitrary cuts to generate a catalog of well behaved objects

fluxlim_ref = 10**(-0.4*(mmax-30))
snr_cut = 0.2

flux_name = 'mof_flux_'
fluxerr_name = 'mof_fluxerr_'
mag_name = 'mag_'
magerr_name = 'magerr_'

# We keep everything brighter than mag = 26 in all bands
# We do a S/N cut based on snr_cut
for b in filters:
    data = data[data[flux_name+b] > fluxlim_ref]
    data = data[data[magerr_name+b] <= snr_cut]
    
nobj = data.size
print(nobj)

fluxes = np.zeros((len(filters), nobj))
fluxerrs = np.zeros((len(filters), nobj))
mags = np.zeros((len(filters), nobj))
magerrs = np.zeros((len(filters), nobj))

redshifts = data['z_bpz']
types = data['template_type']

for i, b in enumerate(filters):
    fluxes[i] = np.array(data[flux_name+b])
    fluxerrs[i] = np.array(data[fluxerr_name+b])
    mags[i] = np.array(data[mag_name+b])
    magerrs[i] = np.array(data[magerr_name+b])

f, axes = plt.subplots(2, len(filters), figsize=(16,5), sharey='row')
for i,b in enumerate(filters):
    axes[0,i].hist(mags[i], range = (mmin, mmax), bins = 50, histtype='step')
    axes[1,i].hist(magerrs[i], bins = 50, histtype='step', range = (0,0.1))
    axes[0,i].set_title(b)
plt.subplots_adjust(wspace=0, hspace= 0.5)
# Out:
# 44584

# %%
true_z = plt.hist(redshifts, range = (zmin,zmax), bins = nz_coarse, histtype = 'step')[0]

# %% [markdown]
# # Obtain the flux-redshift models
#
# The observed photon flux is:
#
# $$ F_{b,t} = \int_0^{\infty}\,\frac{L_t[\nu(1+z)]}{\nu}\,W_b(\nu)\,d\nu$$
#
# Which is the number of photons per unit time per unit area observed trough a setup with instrumental response $W_b(\nu)$ from a source at redshift $z$ with restframe Spectral Energy Density (SED) $L_t[\nu]$
#
# Changing variables from frequency to wavelength we have
#
# $$\frac{d\nu}{d\lambda}L_t(\nu) = L_t(\lambda) \Rightarrow L_t(\nu) = -L_t(\lambda)\frac{\lambda^2}{c}$$
#
# At the same time, $d\nu = \frac{-c}{\lambda^2}d\lambda$, and we have tabulated values for $W_b(\lambda)$
#
# $$ F_{b,t} = \int_0^{\infty}\frac{\lambda}{c}\,L_t[\lambda(1+z)] \frac{-\lambda^2}{c} \,W_b(\lambda)\,\frac{-c}{\lambda^2} d\lambda  = \int_0^{\infty}\left[L_t[\lambda(1+z)]\,\lambda^2\right] \,\left[W_b(\lambda)\,\frac{1}{c\lambda}\right] d\lambda$$

# %%
# Approximate luminosity distance for flat LCDM
def DL(z):
    return np.exp(30.5 * z**0.04 - 21.7)


# We will now use the BPZ routines to load the flux-redshift model for each template.
# We'll have interpolated and discretized versions
nf = len(filters)

f_mod = np.zeros((nz_fine,nt,nf))                  # This is the fine version of the flux-redshift model
f_mod_interps = np.zeros((nt, nf), dtype=interp1d) # This basically allows us to evaluate at any z

lambdaRef = 7e3 # Wavelength at which the templates are normalized

for it in range(nt):
    seddata = np.genfromtxt('./seds/' + template_names[it] + '.sed')
    seddata[:, 1] *= seddata[:, 0]**2. # light speed in angstrom/s ?? What if I remove this...
    ref = np.interp(lambdaRef, seddata[:, 0], seddata[:, 1])
    seddata[:, 1] /= ref
    sed_interp = interp1d(seddata[:, 0], seddata[:, 1])
    
    for jf in range(nf):
        filter_data = np.genfromtxt('./filters/' + filters[jf] + '_DES_Y1.res')
#         filter_data = np.genfromtxt('./filters/' + filters[jf] + '.dat')
        xf, yf = filter_data[:, 0], filter_data[:, 1]
        yf /= xf  # divide by lambda
#         Only consider range where >1% max
        ind = np.where(yf > 0.01*np.max(yf))[0]
        lambdaMin, lambdaMax = xf[ind[0]], xf[ind[-1]]
        norm = np.trapz(yf, x=xf)
        
        for iz in range(nz_fine):
            opz = (z_grid_fine[iz] + 1.0)
            xf_z = np.linspace(lambdaMin / opz, lambdaMax / opz, num=5000)
            yf_z = interp1d(xf / opz, yf)(xf_z)
            ysed = sed_interp(xf_z)
            f_mod[iz, it, jf] = np.trapz(ysed * yf_z, x=xf_z) / norm
            f_mod[iz, it, jf] *= opz**2. / DL(z_grid_fine[iz])**2. / (4*np.pi)
#         This is an actual interpolator. Given any z value it will return the interpolation at that z
        f_mod_interps[it, jf] = InterpolatedUnivariateSpline(z_grid_fine, f_mod[:, it, jf])
        
f_mod_log = -2.5*np.log10(f_mod) # Flux-redshift model converted to magnitude-redshift model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d9f5c620e143> in <module>()
#      14
#      15 for it in range(nt):
# ---> 16     seddata = np.genfromtxt('./seds/' + template_names[it] + '.sed')
#      17     seddata[:, 1] *= seddata[:, 0]**2. # light speed in angstrom/s ?? What if I remove this...
#      18     ref = np.interp(lambdaRef, seddata[:, 0], seddata[:, 1])
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2029             # Raise an exception ?
#    2030             if invalid_raise:
# -> 2031                 raise ValueError(errmsg)
#    2032             # Issue a warning ?
#    2033             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 3 columns instead of 2)
#     Line #3 (got 3 columns instead of 2)
#     Line #5 (got 3 columns instead of 2)
#     Line #6 (got 3 columns instead of 2)
#     Line #7 (got 3 columns instead of 2)
#     Line #8 (got 9 columns instead of 2)
#     Line #9 (got 5 columns instead of 2)
#     Line #10 (got 3 columns instead of 2)
#     Line #11 (got 3 columns instead of 2)
#     Line #12 (got 3 columns instead of 2)
#     Line #13 (got 3 columns instead of 2)
#     Line #14 (got 3 columns instead of 2)
#     Line #15 (got 9 columns instead of 2)
#     Line #16 (got 5 columns instead of 2)
#     Line #17 (got 3 columns instead of 2)
#     Line #19 (got 9 columns instead of 2)
#     Line #20 (got 5 columns instead of 2)
#     Line #21 (got 7 columns instead of 2)
#     Line #22 (got 5 columns instead of 2)
#     Line #23 (got 5 columns instead of 2)
#     Line #26 (got 1 columns instead of 2)
#     Line #27 (got 1 columns instead of 2)
#     Line #28 (got 1 columns instead of 2)
#     Line #29 (got 1 columns instead of 2)
#     Line #30 (got 1 columns instead of 2)
#     Line #32 (got 3 columns instead of 2)
#     Line #33 (got 3 columns instead of 2)
#     Line #34 (got 3 columns instead of 2)
#     Line #38 (got 3 columns instead of 2)
#     Line #41 (got 4 columns instead of 2)
#     Line #42 (got 4 columns instead of 2)
#     Line #43 (got 3 columns instead of 2)
#     Line #44 (got 5 columns instead of 2)
#     Line #46 (got 5 columns instead of 2)
#     Line #47 (got 6 columns instead of 2)
#     Line #48 (got 6 columns instead of 2)
#     Line #49 (got 6 columns instead of 2)
#     Line #50 (got 6 columns instead of 2)
#     Line #51 (got 3 columns instead of 2)
#     Line #56 (got 1 columns instead of 2)
#     Line #58 (got 7 columns instead of 2)
#     Line #61 (got 3 columns instead of 2)
#     Line #62 (got 4 columns instead of 2)
#     Line #67 (got 11 columns instead of 2)
#     Line #68 (got 4 columns instead of 2)
#     Line #69 (got 4 columns instead of 2)
#     Line #70 (got 4 columns instead of 2)
#     Line #71 (got 4 columns instead of 2)
#     Line #72 (got 4 columns instead of 2)
#     Line #73 (got 4 columns instead of 2)
#     Line #74 (got 4 columns instead of 2)
#     Line #75 (got 1 columns instead of 2)
#     Line #77 (got 3 columns instead of 2)
#     Line #78 (got 122 columns instead of 2)
#     Line #80 (got 1 columns instead of 2)
#     Line #81 (got 1 columns instead of 2)
#     Line #82 (got 3 columns instead of 2)
#     Line #83 (got 5 columns instead of 2)
#     Line #84 (got 5 columns instead of 2)
#     Line #85 (got 5 columns instead of 2)
#     Line #86 (got 1 columns instead of 2)
#     Line #87 (got 5 columns instead of 2)
#     Line #88 (got 1 columns instead of 2)
#     Line #89 (got 1 columns instead of 2)
#     Line #91 (got 1 columns instead of 2)
#     Line #92 (got 3 columns instead of 2)
#     Line #93 (got 3 columns instead of 2)
#     Line #94 (got 3 columns instead of 2)
#     Line #95 (got 4 columns instead of 2)
#     Line #96 (got 8 columns instead of 2)
#     Line #97 (got 3 columns instead of 2)
#     Line #99 (got 3 columns instead of 2)
#     Line #100 (got 17 columns instead of 2)
#     Line #101 (got 3 columns instead of 2)
#     Line #104 (got 1 columns instead of 2)
#     Line #105 (got 1 columns instead of 2)
#     Line #106 (got 1 columns instead of 2)
#     Line #107 (got 1 columns instead of 2)
#     Line #108 (got 1 columns instead of 2)
#     Line #109 (got 7 columns instead of 2)
#     Line #110 (got 1 columns instead of 2)
#     Line #111 (got 4 columns instead of 2)
#     Line #112 (got 5 columns instead of 2)
#     Line #113 (got 1 columns instead of 2)
#     Line #114 (got 1 columns instead of 2)
#     Line #115 (got 1 columns instead of 2)
#     Line #116 (got 6 columns instead of 2)
#     Line #117 (got 12 columns instead of 2)
#     Line #118 (got 6 columns instead of 2)
#     Line #119 (got 6 columns instead of 2)
#     Line #121 (got 6 columns instead of 2)
#     Line #122 (got 1 columns instead of 2)
#     Line #124 (got 1 columns instead of 2)
#     Line #125 (got 3 columns instead of 2)
#     Line #126 (got 9 columns instead of 2)
#     Line #127 (got 1 columns instead of 2)
#     Line #128 (got 1 columns instead of 2)
#     Line #129 (got 1 columns instead of 2)
#     Line #130 (got 7 columns instead of 2)
#     Line #131 (got 1 columns instead of 2)
#     Line #132 (got 1 columns instead of 2)
#     Line #133 (got 1 columns instead of 2)
#     Line #134 (got 1 columns instead of 2)
#     Line #135 (got 6 columns instead of 2)
#     Line #136 (got 3 columns instead of 2)
#     Line #137 (got 5 columns instead of 2)
#     Line #138 (got 5 columns instead of 2)
#     Line #139 (got 1 columns instead of 2)
#     Line #140 (got 1 columns instead of 2)
#     Line #141 (got 1 columns instead of 2)
#     Line #142 (got 1 columns instead of 2)
#     Line #145 (got 3 columns instead of 2)
#     Line #149 (got 6 columns instead of 2)
#     Line #150 (got 6 columns instead of 2)
#     Line #151 (got 1 columns instead of 2)
#     Line #153 (got 1 columns instead of 2)
#     Line #154 (got 1 columns instead of 2)
#     Line #155 (got 1 columns instead of 2)
#     Line #157 (got 5 columns instead of 2)
#     Line #159 (got 1 columns instead of 2)
#     Line #161 (got 1 columns instead of 2)
#     Line #162 (got 1 columns instead of 2)
#     Line #164 (got 4 columns instead of 2)
#     Line #165 (got 1 columns instead of 2)
#     Line #166 (got 1 columns instead of 2)
#     Line #167 (got 3 columns instead of 2)
#     Line #168 (got 6 columns instead of 2)
#     Line #169 (got 5 columns instead of 2)
#     Line #170 (got 7 columns instead of 2)
#     Line #171 (got 1 columns instead of 2)
#     Line #172 (got 5 columns instead of 2)
#     Line #174 (got 1 columns instead of 2)
#     Line #176 (got 1 columns instead of 2)
#     Line #177 (got 1 columns instead of 2)
#     Line #179 (got 5 columns instead of 2)
#     Line #180 (got 1 columns instead of 2)
#     Line #181 (got 1 columns instead of 2)
#     Line #182 (got 3 columns instead of 2)
#     Line #183 (got 3 columns instead of 2)
#     Line #184 (got 3 columns instead of 2)
#     Line #185 (got 3 columns instead of 2)
#     Line #186 (got 3 columns instead of 2)
#     Line #187 (got 3 columns instead of 2)
#     Line #188 (got 3 columns instead of 2)
#     Line #189 (got 3 columns instead of 2)
#     Line #190 (got 3 columns instead of 2)
#     Line #191 (got 1 columns instead of 2)
#     Line #192 (got 5 columns instead of 2)
#     Line #194 (got 1 columns instead of 2)
#     Line #196 (got 1 columns instead of 2)
#     Line #197 (got 1 columns instead of 2)
#     Line #198 (got 5 columns instead of 2)
#     Line #200 (got 1 columns instead of 2)
#     Line #202 (got 1 columns instead of 2)
#     Line #203 (got 1 columns instead of 2)
#     Line #204 (got 4 columns instead of 2)
#     Line #205 (got 1 columns instead of 2)
#     Line #206 (got 1 columns instead of 2)
#     Line #208 (got 4 columns instead of 2)
#     Line #209 (got 1 columns instead of 2)
#     Line #210 (got 1 columns instead of 2)
#     Line #211 (got 5 columns instead of 2)
#     Line #212 (got 1 columns instead of 2)
#     Line #213 (got 1 columns instead of 2)
#     Line #214 (got 3 columns instead of 2)
#     Line #215 (got 4 columns instead of 2)
#     Line #216 (got 1 columns instead of 2)
#     Line #217 (got 1 columns instead of 2)
#     Line #218 (got 4 columns instead of 2)
#     Line #219 (got 1 columns instead of 2)
#     Line #220 (got 1 columns instead of 2)
#     Line #221 (got 4 columns instead of 2)
#     Line #222 (got 1 columns instead of 2)
#     Line #223 (got 1 columns instead of 2)
#     Line #224 (got 4 columns instead of 2)
#     Line #225 (got 1 columns instead of 2)
#     Line #226 (got 1 columns instead of 2)
#     Line #227 (got 1 columns instead of 2)
#     Line #228 (got 5 columns instead of 2)
#     Line #230 (got 1 columns instead of 2)
#     Line #233 (got 1 columns instead of 2)
#     Line #234 (got 5 columns instead of 2)
#     Line #235 (got 1 columns instead of 2)
#     Line #236 (got 1 columns instead of 2)
#     Line #237 (got 3 columns instead of 2)
#     Line #238 (got 4 columns instead of 2)
#     Line #240 (got 1 columns instead of 2)
#     Line #241 (got 6 columns instead of 2)
#     Line #242 (got 1 columns instead of 2)
#     Line #243 (got 1 columns instead of 2)
#     Line #244 (got 1 columns instead of 2)
#     Line #245 (got 5 columns instead of 2)
#     Line #247 (got 1 columns instead of 2)
#     Line #249 (got 3 columns instead of 2)
#     Line #250 (got 1 columns instead of 2)
#     Line #252 (got 4 columns instead of 2)
#     Line #253 (got 3 columns instead of 2)
#     Line #254 (got 1 columns instead of 2)
#     Line #255 (got 3 columns instead of 2)
#     Line #256 (got 5 columns instead of 2)
#     Line #257 (got 1 columns instead of 2)
#     Line #258 (got 1 columns instead of 2)
#     Line #259 (got 5 columns instead of 2)
#     Line #260 (got 1 columns instead of 2)
#     Line #261 (got 1 columns instead of 2)
#     Line #262 (got 5 columns instead of 2)
#     Line #263 (got 1 columns instead of 2)
#     Line #264 (got 1 columns instead of 2)
#     Line #265 (got 5 columns instead of 2)
#     Line #266 (got 1 columns instead of 2)
#     Line #267 (got 1 columns instead of 2)
#     Line #268 (got 1 columns instead of 2)
#     Line #269 (got 5 columns instead of 2)
#     Line #271 (got 1 columns instead of 2)
#     Line #273 (got 1 columns instead of 2)
#     Line #274 (got 1 columns instead of 2)
#     Line #275 (got 3 columns instead of 2)
#     Line #276 (got 4 columns instead of 2)
#     Line #277 (got 1 columns instead of 2)
#     Line #278 (got 1 columns instead of 2)
#     Line #279 (got 1 columns instead of 2)
#     Line #280 (got 6 columns instead of 2)
#     Line #282 (got 1 columns instead of 2)
#     Line #284 (got 1 columns instead of 2)
#     Line #285 (got 1 columns instead of 2)
#     Line #286 (got 3 columns instead of 2)
#     Line #287 (got 4 columns instead of 2)
#     Line #288 (got 1 columns instead of 2)
#     Line #289 (got 1 columns instead of 2)
#     Line #290 (got 1 columns instead of 2)
#     Line #291 (got 7 columns instead of 2)
#     Line #292 (got 4 columns instead of 2)
#     Line #293 (got 4 columns instead of 2)
#     Line #294 (got 3 columns instead of 2)
#     Line #295 (got 1 columns instead of 2)
#     Line #296 (got 6 columns instead of 2)
#     Line #297 (got 3 columns instead of 2)
#     Line #298 (got 1 columns instead of 2)
#     Line #300 (got 4 columns instead of 2)
#     Line #301 (got 1 columns instead of 2)
#     Line #302 (got 1 columns instead of 2)
#     Line #303 (got 1 columns instead of 2)
#     Line #305 (got 4 columns instead of 2)
#     Line #306 (got 1 columns instead of 2)
#     Line #308 (got 4 columns instead of 2)
#     Line #309 (got 1 columns instead of 2)
#     Line #311 (got 6 columns instead of 2)
#     Line #312 (got 1 columns instead of 2)
#     Line #314 (got 4 columns instead of 2)
#     Line #315 (got 1 columns instead of 2)
#     Line #317 (got 4 columns instead of 2)
#     Line #318 (got 1 columns instead of 2)
#     Line #320 (got 6 columns instead of 2)
#     Line #321 (got 1 columns instead of 2)
#     Line #322 (got 1 columns instead of 2)
#     Line #323 (got 1 columns instead of 2)
#     Line #324 (got 1 columns instead of 2)
#     Line #326 (got 3 columns instead of 2)
#     Line #331 (got 5 columns instead of 2)
#     Line #333 (got 6 columns instead of 2)
#     Line #334 (got 5 columns instead of 2)
#     Line #335 (got 3 columns instead of 2)
#     Line #336 (got 4 columns instead of 2)
#     Line #337 (got 16 columns instead of 2)
#     Line #339 (got 1 columns instead of 2)
#     Line #340 (got 3 columns instead of 2)
#     Line #341 (got 1 columns instead of 2)
#     Line #342 (got 1 columns instead of 2)
#     Line #343 (got 1 columns instead of 2)
#     Line #345 (got 1 columns instead of 2)
#     Line #346 (got 1 columns instead of 2)
#     Line #348 (got 3 columns instead of 2)
#     Line #349 (got 1 columns instead of 2)
#     Line #351 (got 1 columns instead of 2)
#     Line #352 (got 3 columns instead of 2)
#     Line #353 (got 3 columns instead of 2)
#     Line #355 (got 3 columns instead of 2)
#     Line #356 (got 3 columns instead of 2)
#     Line #360 (got 8 columns instead of 2)
#     Line #361 (got 6 columns instead of 2)
#     Line #363 (got 17 columns instead of 2)
#     Line #364 (got 5 columns instead of 2)
#     Line #366 (got 12 columns instead of 2)
#     Line #367 (got 23 columns instead of 2)
#     Line #369 (got 7 columns instead of 2)
#     Line #370 (got 1 columns instead of 2)
#     Line #371 (got 1 columns instead of 2)
#     Line #372 (got 1 columns instead of 2)
#     Line #373 (got 1 columns instead of 2)
#     Line #374 (got 1 columns instead of 2)
#     Line #375 (got 3 columns instead of 2)
#     Line #376 (got 1 columns instead of 2)
#     Line #378 (got 1 columns instead of 2)
#     Line #379 (got 1 columns instead of 2)
#     Line #381 (got 1 columns instead of 2)
#     Line #382 (got 1 columns instead of 2)
#     Line #384 (got 1 columns instead of 2)
#     Line #385 (got 1 columns instead of 2)
#     Line #387 (got 1 columns instead of 2)
#     Line #388 (got 1 columns instead of 2)
#     Line #389 (got 1 columns instead of 2)
#     Line #391 (got 9 columns instead of 2)
#     Line #393 (got 1 columns instead of 2)
#     Line #394 (got 11 columns instead of 2)
#     Line #395 (got 1 columns instead of 2)
#     Line #396 (got 1 columns instead of 2)
#     Line #398 (got 3 columns instead of 2)
#     Line #401 (got 5 columns instead of 2)
#     Line #402 (got 3 columns instead of 2)
#     Line #403 (got 4 columns instead of 2)
#     Line #404 (got 1 columns instead of 2)
#     Line #407 (got 12 columns instead of 2)
#     Line #408 (got 3 columns instead of 2)
#     Line #409 (got 1 columns instead of 2)
#     Line #410 (got 1 columns instead of 2)
#     Line #411 (got 1 columns instead of 2)
#     Line #413 (got 19 columns instead of 2)
#     Line #414 (got 1 columns instead of 2)
#     Line #415 (got 1 columns instead of 2)
#     Line #416 (got 3 columns instead of 2)
#     Line #418 (got 5 columns instead of 2)
#     Line #419 (got 29 columns instead of 2)
#     Line #421 (got 1 columns instead of 2)
#     Line #422 (got 1 columns instead of 2)
#     Line #423 (got 1 columns instead of 2)
#     Line #425 (got 1 columns instead of 2)
#     Line #426 (got 1 columns instead of 2)
#     Line #428 (got 1 columns instead of 2)
#     Line #429 (got 3 columns instead of 2)
#     Line #431 (got 3 columns instead of 2)
#     Line #433 (got 6 columns instead of 2)
#     Line #435 (got 1 columns instead of 2)
#     Line #436 (got 1 columns instead of 2)
#     Line #437 (got 33 columns instead of 2)
#     Line #438 (got 1 columns instead of 2)
#     Line #440 (got 1 columns instead of 2)
#     Line #441 (got 1 columns instead of 2)
#     Line #443 (got 3 columns instead of 2)
#     Line #445 (got 18 columns instead of 2)
#     Line #446 (got 21 columns instead of 2)
#     Line #447 (got 1 columns instead of 2)
#     Line #448 (got 1 columns instead of 2)
#     Line #451 (got 4 columns instead of 2)
#     Line #452 (got 4 columns instead of 2)
#     Line #453 (got 8 columns instead of 2)
#     Line #454 (got 1 columns instead of 2)
#     Line #456 (got 1 columns instead of 2)
#     Line #459 (got 1 columns instead of 2)
#     Line #460 (got 1 columns instead of 2)
#     Line #462 (got 1 columns instead of 2)
#     Line #463 (got 1 columns instead of 2)
#     Line #465 (got 1 columns instead of 2)
#     Line #466 (got 1 columns instead of 2)
#     Line #467 (got 1 columns instead of 2)
#     Line #468 (got 1 columns instead of 2)
#     Line #471 (got 1 columns instead of 2)
#     Line #472 (got 1 columns instead of 2)

# %% [markdown]
# These are the tracks generated by redshifting the templates, itegrating them over the filter response curve, and calculating the color by comparing the magnitudes of two consecutive filters.
# On top of this, we plot the observed colors of galaxies tagged with a specific template in the GOLD catalogue.
# Since the tagging is made considering an interpolation between templates, we group together all objects around the central value for the template.
# Some of them seem to be in good agreement, but differences can be caused by the fact that the set of templates used by BPZv1 is possiby different, and the fliter response curves *could* be different aswell.

# %%
d_template = 0.0
f, axes = plt.subplots(nt, nf-1, figsize=(15,nt*1.5))

for i in range(nt):
    types_t = [(types >= i-d_template) & ((types <= i+d_template))]
    mags_t = mags.T[tuple(types_t)]
    redshift_t =  redshifts[tuple(types_t)]

    for band in range(nf-1):
        axes[i,band].plot(redshift_t, mags_t[:,band] - mags_t[:,band+1], '.', c = 'k')
        color = -2.5*np.log10(f_mod[:,i,band] / f_mod[:,i,band+1])
        axes[i,band].plot(z_grid_fine, color, lw=2, c='m')

# %% [markdown]
# This is a scale-free likelihood function, marginalizing over the scales of the fluxes, following the formulation presented in Benitez (2000)

# %%
# This is a scale-free likelihood function, marginalizing over the scale of the fluxes
# This follows the formulation presented in Benitez (2000)
def scalefree_flux_likelihood(f_obs, f_obs_var, f_mod, returnChi2=False):
    nz, nt, nf = f_mod.shape
    var = f_obs_var  # nz * nt * nf
    invvar = np.where(f_obs/var < 1e-6, 0.0, var**-1.0)   # nz * nt * nf
    FOT = np.sum(f_mod * f_obs * invvar, axis=2)  # nz * nt
    FTT = np.sum(f_mod**2 * invvar, axis=2)  # nz * nt
    FOO = np.dot(invvar, f_obs**2)  # nz * nt
    ellML = FOT / FTT
    chi2 = FOO - FOT**2.0 / FTT  # nz * nt
    like = np.exp(-0.5*chi2) / np.sqrt(FTT)  # nz * nt
    if returnChi2:
        return chi2 + FTT, ellML
    else:
        return like, ellML

# %%
# Let's use the same templates to compute the likelihood functions of all these objects
# Compute likelihood for each object

bpz_like_fine_multitypes = np.zeros((nobj, nz_fine, nt), dtype=float) # Binned liklihood at full resolution
bpz_like_multitypes = np.zeros((nobj, nz_coarse, nt), dtype=float) # Coarce binned likelihood
new_f_mod = f_mod[:,:,:] / f_mod.mean(axis=2)[:, :, None] # Why is this exactly?

for i in range(nobj):
    if i%1000 == 0:
        print(i, end=' ')
    # This scales both the errors and the fluxes to reasonable numbers.
    # The values change but relative peaks do not. It could be 1 as well and represent no change
    scafac = 1/np.mean(fluxes[:,i]) 
    ff, ellML = scalefree_flux_likelihood(scafac*fluxes[:,i], (scafac*fluxerrs[:,i])**2, new_f_mod)
    bpz_like_fine_multitypes[i,:,:] = ff # Fine resolution
    for kk in range(nz_coarse):
        bpz_like_multitypes[i,kk,:] = np.mean(ff[kk*fac:(kk+1)*fac,:], axis=0) # Re-bin
# Out:
# 0 1000 2000 3000 4000 5000 6000 7000 8000 9000 10000 11000 12000 13000 14000 15000 16000 17000 18000 19000 20000 21000 22000 23000 24000 25000 26000 27000 28000 29000 30000 31000 32000 33000 34000 35000 36000 37000 38000 39000 40000 41000 42000 43000 44000

# %%
# plot likelihood function for a few randomly picked objects
# color coded by type.
fig2, axs = plt.subplots(4, 3, figsize=(12, 12), sharex=True, sharey=False)
axs = axs.ravel()
ri = np.random.choice(np.arange(nobj), axs.size, replace=False)
# ri = np.arange(12)
for i in range(len(ri)):
    theax = axs[i]
    theax.plot(z_grid_fine, bpz_like_fine_multitypes[ri[i],:,:], lw=2)
    theax.plot(z_grid_coarse, bpz_like_multitypes[ri[i],:,:], lw=2,drawstyle='steps')
    theax.axvline(redshifts[ri[i]], ls='dashed', c='k')
#     theax.set_title(r'Likelihood $p(F|z,t)$')
#     theax.set_xlabel(r'Redshift $z$')

# %%
# Also need to multiply with gaussian likelihood for reference magnitude, since we will infer p(z, t, m)
def gauss_like_int(grid_edges, mus, sigmas):
    nobj = mus.size
    nz = grid_edges.size-1
    res = np.zeros((nobj, nz))
    fac = np.sqrt(2) * sigmas
    for iz, (zlo, zhi) in enumerate(zip(grid_edges[:-1], grid_edges[1:])):
        res[:,iz] = np.abs(-(erfc((zhi-mus)/fac) - erfc((zlo-mus)/fac))/2.0)
    return res

# %%
imag_grid_edges = np.linspace(mmin, mmax, num=nm+1)
imag_grid = (imag_grid_edges[1:] + imag_grid_edges[:-1])/2.0
bpz_like_ztm = np.zeros((nobj, nz_coarse, nt, nm), dtype=float)
imaglike = gauss_like_int(imag_grid_edges, mags[reffilter,:], magerrs[reffilter,:])
for i in range(nobj):
    bpz_like_ztm[i,:,:,:] = np.outer(bpz_like_multitypes[i,:,:], imaglike[i,:]).reshape((nz_coarse, nt, nm))
    
imaglocs = np.zeros((nobj,), dtype=int)
for iz, (zlo, zhi) in enumerate(zip(imag_grid_edges[:-1], imag_grid_edges[1:])):
    ind = np.logical_and(mags[reffilter] > zlo, mags[reffilter] <= zhi)
    if ind.sum()>0:
        imaglocs[ind] = iz

# %%
# Compute z_MAP in case it is useful, and also write likelihoods to 4 files
def chunks(seq, num):
    avg = len(seq) / float(num)
    out = []
    last = 0.0
    while last < len(seq):
        out.append(seq[int(last):int(last + avg)])
        last += avg
    return out

# Save each chunk of 4D python numpy array into files
nchunks = 4
lines_out = np.arange(nobj)#lines#np.arange(nobj_selec)
for i, ind in enumerate(chunks(lines_out, nchunks)):
    fname = 'bpz_DES_GOLD_Y1_ztm_'+str(nchunks)+'_'+str(i+1)+'.npy'
    np.save(fname, bpz_like_ztm[ind,:,:,:])

# %%
# !mpirun -np 4 ./bayeshist.py bpz_DES_GOLD_Y1_ztm_4 1000
# Out:
# ('Input parameters:', ['./bayeshist.py', 'bpz_DES_GOLD_Y1_ztm_4', '1000'])
# Running on 4 cores
# ('Read file', 'bpz_DES_GOLD_Y1_ztm_4_2.npy', 'and found', 11146, 'objects')
# ('Read file', 'bpz_DES_GOLD_Y1_ztm_4_3.npy', 'and found', 11146, 'objects')
# ('Read file', 'bpz_DES_GOLD_Y1_ztm_4_1.npy', 'and found', 11146, 'objects')
# ('Read file', 'bpz_DES_GOLD_Y1_ztm_4_4.npy', 'and found', 11146, 'objects')
# Broadcasted hbs
# ./bayeshist.py:101: RuntimeWarning: invalid value encountered in divide
#   cumsumweights /= cumsumweights[-1,:]
# ./bayeshist.py:101: RuntimeWarning: invalid value encountered in divide
#   cumsumweights /= cumsumweights[-1,:]
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in greater
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in greater
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:101: RuntimeWarning: invalid value encountered in divide
#   cumsumweights /= cumsumweights[-1,:]
# ./bayeshist.py:101: RuntimeWarning: invalid value encountered in divide
#   cumsumweights /= cumsumweights[-1,:]
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in less_equal
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in less_equal
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in greater
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in greater
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in less_equal
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ./bayeshist.py:103: RuntimeWarning: invalid value encountered in less_equal
#   cond = np.logical_and(pos > cumsumweights[:-1,:], pos <= cumsumweights[1:,:])
# ('Saving', 7, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.74', 'sec per sample)')
# ('Saving', 14, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.67', 'sec per sample)')
# ('Saving', 21, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.65', 'sec per sample)')
# ('Saving', 28, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.65', 'sec per sample)')
# ('Saving', 35, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.64', 'sec per sample)')
# ('Saving', 42, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.64', 'sec per sample)')
# ('Saving', 49, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.63', 'sec per sample)')
# ('Saving', 56, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.63', 'sec per sample)')
# ('Saving', 63, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.63', 'sec per sample)')
# ('Saving', 70, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.63', 'sec per sample)')
# ('Saving', 77, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.63', 'sec per sample)')
# ('Saving', 84, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 91, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 98, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 105, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 112, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 119, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 126, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 133, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 140, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 147, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 154, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 161, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 168, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 175, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.62', 'sec per sample)')
# ('Saving', 182, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 189, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 196, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 203, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 210, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 217, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 224, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 231, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 238, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 245, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 252, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 259, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 266, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 273, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 280, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 287, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 294, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 301, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 308, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 315, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 322, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 329, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 336, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 343, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 350, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 357, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 364, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 371, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 378, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 385, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 392, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 399, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 406, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 413, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 420, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 427, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 434, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 441, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 448, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 455, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 462, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 469, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 476, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 483, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 490, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 497, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 504, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 511, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 518, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.61', 'sec per sample)')
# ('Saving', 525, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 532, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 539, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 546, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 553, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 560, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 567, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 574, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 581, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 588, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 595, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 602, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 609, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 616, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 623, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 630, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 637, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 644, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 651, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 658, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 665, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 672, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 679, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 686, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')
# ('Saving', 693, 'samples to', 'bpz_DES_GOLD_Y1_ztm_4_post.npy', '(0.60', 'sec per sample)')

# %%
fbs_samples_ztm = np.load('bpz_DES_GOLD_Y1_ztm_4_post.npy')

binsize = (z_grid_coarse[1] - z_grid_coarse[0])
# Same but with type marginalized.
fig, axs = plt.subplots(1, 1, figsize=(10,5), sharex=False)
axs = [axs]
stacked_like = bpz_like_ztm[:,:,:].sum(axis=3).sum(axis=2).sum(axis=0)
stacked_like /= nobj
fbs_samples_z = fbs_samples_ztm[:,:,:,:].sum(axis=3).sum(axis=2)
# hist_noiseless_z = hist_noiseless_ztm.sum(axis=(1,2))
# hist_noiseless_z /= hist_noiseless_z.sum()
df = pd.DataFrame(fbs_samples_z[:,:], columns=np.arange(nz_coarse))
t1 = sns.violinplot(data = df, width=1, scale_hue=False, scale='width', ax=axs[0],
              inner=None, palette="coolwarm", label=r'Recovered distribution')
t3 = axs[0].plot(np.concatenate(([z_grid_coarse[0]/binsize-0.5], z_grid_coarse/binsize+0.5)), 
            np.concatenate(([0], true_z/nobj)), color='k', lw=1.5, 
            drawstyle='steps', label=r'True distribution')
axs[0].legend()
axs[0].set_ylabel(r'$N(z)$')
axs[0].set_xlabel(r'Redshift $z$')
fig.tight_layout()
